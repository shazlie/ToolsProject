# %% [markdown]
# ## We already have the top songs, but at this point we would like to extract 5000 random songs from Spotify
# #### Work by: Naif

# %% [markdown]
# #### 1) Create a function to extract random songs

# %%
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id="a31e2c1446fd4e6aa11476d8532fc939",client_secret="b52f884f9d4f464eba58daf0d5180ea4")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


def get_randomsong_features():
    
    randomSongsArray = ['%25a%25', 'a%25', '%25a',
                        '%25e%25', 'e%25', '%25e',
                        '%25i%25', 'i%25', '%25i',
                        '%25o%25', 'o%25', '%25o',
                        '%25u%25', 'u%25', '%25u']
    randomSongs = random.choice(randomSongsArray)
    
    # generate a random offset
    rand1to1000 = range(1,10000)
    RandomOffset=random.choice(rand1to1000)
    year=range(2000,2018)
    RandomYear=str(random.choice(year))
    songs=sp.search(q='tag:hipster',limit=1,offset=RandomOffset,type="track", market="US")
    items = songs['tracks']['items']
    track=items[0]
    song_id = str(track["id"])
    track_features=sp.audio_features(song_id)
    features = np.array(track_features)[0]
#     gettrack=features['uri']
#     track_info = sp.track(gettrack)
#     artist_name = artist_name = track_info['album']['artists'][0]['name']
#     track_name = track_info['album']['name']
#     track_year = track_info['album']['release_date'][0:4]
    return features

# %% [markdown]
# ##### For loop for 5000 and append to a list

# %%
songs_features3=[]
for i in range(0,2500):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features3.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,artist_popularity,track_pop,duration_ms, time_signature))

# %%
songs_features=[]
for i in range(0,7500):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,artist_popularity,track_pop,duration_ms, time_signature))

# %%
songs_features4=[]
for i in range(0,2250):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features4.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,artist_popularity,track_pop,duration_ms, time_signature))

# %%
#'tag:hipster'
songs_features5=[]
for i in range(0,1500):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features5.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,artist_popularity,track_pop,duration_ms, time_signature))
    allsongs=songs_features+songs_features3+songs_features5

# %%
# Create a DataFrame 
allsongs=songs_features+songs_features3+songs_features5+songs_features4
import pandas as pd

columns_ = ["Year", "Artist", "Track", "Danceability","Energy", "Key", "Loudness", "Mode", "Speechiness", "Acousticness",
          "Instrumentalness", "Liveness", "Valence", "Tempo","Artist Popilarity","Song Popularity", "Duration_ms", "Time Signature"]
df =pd.DataFrame(allsongs, columns=columns_)
df
# Out:
#        Year                      Artist  \
# 0      2010                      Weezer
# 1      2010                         Týr
# 2      2009                 Alex Campos
# 3      2004                  Strung Out
# 4      2009             Various Artists
# 5      2017               Reba McEntire
# 6      2000             Nine Inch Nails
# 7      2000               Bibi und Tina
# 8      2003                  The Format
# 9      2009                         AFI
# 10     2004               Emerson Drive
# 11     2008                   DJ Khaled
# 12     2005                       Bun B
# 13     2010            Middle Class Rut
# 14     2009                 Jack Jezzro
# 15     2008              Zac Brown Band
# 16     2012              Band Of Skulls
# 17     2017             Various Artists
# 18     2007               Dave Matthews
# 19     2015                     The Dip
# 20     2014             Various Artists
# 21     2010                 Clay Walker
# 22     2000             At The Drive In
# 23     2016                       Queen
# 24     2016            Hillsong Worship
# 25     2006                 Amon Amarth
# 26     2008              Wes Montgomery
# 27     2002           Killswitch Engage
# 28     2016                   J. Stalin
# 29     2013                       Emika
# ...     ...                         ...
# 9995   2001                  The Smiths
# 9996   2011                    Cris Cab
# 9997   2007                 Marvin Sapp
# 9998   2005                     Kreator
# 9999   2007                Pretty Ricky
# 10000  2015            Brooks Jefferson
# 10001  2003                  Tito Rojas
# 10001          0.000031    0.2360   0.7350   91.938                 54
# 10002          0.000000    0.1430   0.1560  124.879                 70
# 10003          0.000011    0.1070   0.4070  176.341                 72
# 10004          0.005030    0.1650   0.2320   88.211                 62
# 10005          0.705000    0.1110   0.6870   92.024                 31
# 10006          0.000019    0.2590   0.0935   83.112                 68
# 10007          0.689000    0.2940   0.6960  125.988                 68
# 10008          0.000003    0.3770   0.6950  149.988                 69
# 10009          0.004340    0.1520   0.2780   94.500                 67
# 10010          0.733000    0.5480   0.0439  128.841                  8
# 10011          0.000004    0.0778   0.7770  135.100                 59
# 10012          0.000016    0.0634   0.8630  113.482                 58
# 10013          0.913000    0.1420   0.1530   86.104                 56
# 10014          0.000000    0.5980   0.9410   74.457                 72
# 10015          0.000002    0.0938   0.3010  152.951                 46
# 10016          0.000340    0.0802   0.6800   81.883                 84
# 10017          0.002030    0.2900   0.9740  205.063                 54
# 10018          0.003830    0.2180   0.5080  112.068                 71
# 10019          0.000000    0.0754   0.4100  136.534                 67
# 10020          0.000573    0.1830   0.4680   94.693                 63
# 10021          0.000005    0.2210   0.7720  104.022                 62
# 10022          0.000672    0.6780   0.3960  125.123                 52
# 10023          0.000000    0.2180   0.4690  101.037                 84
# 10024          0.024000    0.1190   0.8950  139.975                 60
#
#        Song Popularity  Duration_ms  Time Signature
# 0                   31       208187               4
# 1                   34       289427               3
# 2                   36       230947               4
# 3                   29       210693               4
# 4                   34       219760               3
# 5                   49       247747               3
# 6                   21       368800               4
# 7                   28        93180               5
# 8                   26       198667               4
# 9                   32       225267               4
# 10                  25       206667               4
# 11                  48       272093               4
# 12                  27       311307               4
# 13                  35       287413               4
# 14                  32       272733               4
# 15                  57       228653               4
# 16                  29       184773               4
# 17                  56       137927               4
# 18                  32       252027               4
# 19                  47       172400               4
# 20                  46       249067               4
# 21                  47       183707               4
# 22                  34       325213               4
# 23                  41       251840               4
# 24                  49       451947               4
# 25                  46       229773               4
# 26                  35       294280               4
# 27                  30       342133               4
# 28                  40       223729               4
# 29                  41       236000               4
# ...                ...          ...             ...
# 9995                31       197800               4
# 9996                32       183584               4
# 9997                29       385573               4
# 9998                46       343920               4
# 9999                37       269520               4
# 10000               42       285513               4
# 10001               42       243960               4
# 10002               29       266947               3
# 10003               45       223530               4
# 10004               43       257360               4
# 10005               38       365693               5
# 10006               59       215920               1
# 10007               24       431160               4
# 10008               38       261642               4
# 10009               40       211947               4
# 10010               58       257280               4
# 10011               29       267587               4
# 10012               32       214133               4
# 10013               34       188347               4
# 10014               65       179564               4
# 10015               48       277973               4
# 10016               56       208933               4
# 10017               35       163040               4
# 10018               44       304533               4
# 10019               31       166185               4
# 10020               36       226867               4
# 10021               60       163320               4
# 10022               27       297453               4
# 10023               68       229213               4
# 10024               30       204040               4
#
# [10025 rows x 18 columns]

# %%
df.to_csv("Finalrandomsongs.csv", sep='\t')
