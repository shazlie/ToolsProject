# %% [markdown]
# ## We already have the top songs, but at this point we would like to extract 5000 random songs from Spotify
# #### Work by: Naif

# %% [markdown]
# #### 1) Create a function to extract random songs

# %%
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id="a31e2c1446fd4e6aa11476d8532fc939",client_secret="b52f884f9d4f464eba58daf0d5180ea4")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


def get_randomsong_features():
    
    randomSongsArray = ['%25a%25', 'a%25', '%25a',
                        '%25e%25', 'e%25', '%25e',
                        '%25i%25', 'i%25', '%25i',
                        '%25o%25', 'o%25', '%25o',
                        '%25u%25', 'u%25', '%25u']
    randomSongs = random.choice(randomSongsArray)
    
    # generate a random offset
    rand1to1000 = range(1,10000)
    RandomOffset=random.choice(rand1to1000)
    year=range(2000,2018)
    RandomYear=str(random.choice(year))
    songs=sp.search(q='year:'+RandomYear,limit=1,offset=RandomOffset,type="track", market="US")
    items = songs['tracks']['items']
    track=items[0]
    song_id = str(track["id"])
    track_features=sp.audio_features(song_id)
    features = np.array(track_features)[0]
#     gettrack=features['uri']
#     track_info = sp.track(gettrack)
#     artist_name = artist_name = track_info['album']['artists'][0]['name']
#     track_name = track_info['album']['name']
#     track_year = track_info['album']['release_date'][0:4]
    return features

# %% [markdown]
# ##### For loop for 5000 and append to a list

# %%
songs_features=[]
for i in range(0,9200):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,track_pop,artist_popularity,duration_ms, time_signature))
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id="a31e2c1446fd4e6aa11476d8532fc939",client_secret="b52f884f9d4f464eba58daf0d5180ea4")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


def get_randomsong_features2():
    
    randomSongsArray = ['%25a%25', 'a%25', '%25a',
                        '%25e%25', 'e%25', '%25e',
                        '%25i%25', 'i%25', '%25i',
                        '%25o%25', 'o%25', '%25o',
                        '%25u%25', 'u%25', '%25u']
    randomSongs = random.choice(randomSongsArray)
    
    # generate a random offset
    rand1to1000 = range(1,10000)
    RandomOffset=random.choice(rand1to1000)
    year=range(2000,2018)
    RandomYear=str(random.choice(year))
    songs=sp.search(q='tag:hipster',limit=1,offset=RandomOffset,type="track", market="US")
    items = songs['tracks']['items']
    track=items[0]
    song_id = str(track["id"])
    track_features=sp.audio_features(song_id)
    features = np.array(track_features)[0]
#     gettrack=features['uri']
#     track_info = sp.track(gettrack)
#     artist_name = artist_name = track_info['album']['artists'][0]['name']
#     track_name = track_info['album']['name']
#     track_year = track_info['album']['release_date'][0:4]
    return features

# %%
#'tag:hipster'
songs_features1=[]
for i in range(0,1000):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features2().values()
    track_info = sp.track(uri)
    artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['name']
    artists=sp.search('artist:'+artist_name+'*' , type='artist')
    try: 
        artist_popularity = artists['artists']['items'][0]['popularity']
    except: 
        artist_popularity = 0 
    track_year = track_info['album']['release_date'][0:4]
    track_pop=track_info['popularity']
    songs_features1.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo, track_pop,artist_popularity,duration_ms, time_signature))
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
# Create a DataFrame 
allsongs=songs_features+songs_features1
import pandas as pd

columns_ = ["Year", "Artist", "Track", "Danceability","Energy", "Key", "Loudness", "Mode", "Speechiness", "Acousticness",
          "Instrumentalness", "Liveness", "Valence", "Tempo",'Track_Popularity',"Artist_Popularity", "Duration_ms", "Time Signature"]
df =pd.DataFrame(allsongs, columns=columns_)
df
# Out:
#        Year                                             Artist  \
# 0      2003                                           Coldplay
# 1      2005                                          The Jacka
# 2      2004                                      Marco Borsato
# 3      2005                                        Smash Mouth
# 4      2017                                               Yuri
# 5      2005                                       Ana Carolina
# 6      2012                                         Chief Keef
# 7      2017                                          YNW Melly
# 8      2000                           Bob Marley & The Wailers
# 9      2014                                            J. Cole
# 10     2011                                 Conjunto Atardecer
# 11     2016                                     Kelly Clarkson
# 12     2004                                         John Mayer
# 13     2012                                           Jay Sean
# 14     2011                                       Art Of Dying
# 15     2001                                            Cri-Cri
# 16     2000                                         Polo Urias
# 17     2008                                    The Revivalists
# 18     2012                                    Various Artists
# 19     2000                                        Céline Dion
# 20     2010                                  Cultura Profética
# 21     2004                               Chitãozinho & Xororó
# 22     2015                                  Sincerely Collins
# 23     2008                                    Various Artists
# 24     2004                                James Newton Howard
# 25     2007                                     Arctic Monkeys
# 26     2005                                          Lil Wayne
# 27     2011                             Florence + The Machine
# 28     2015                                      Mini Mansions
# 29     2002                                    Various Artists
# ...     ...                                                ...
# 10170  2018                                      Banda Imperio
# 10171  2003                                        James Brown
# 10172  2016                                              Lingo
# 10173  2018                                             Dooski
# 10174  2018                                       Charlie Rain
# 10175  2018                                           The Fibs
# 10176  2004                              Mountain Hollow Music
# 10177  2002                                     Zeca Pagodinho
# 10178  2016                                         Brent Best
# 10179  2002                                         Tim Hardin
# 10180  1993                                     Cheryl Wheeler
# 10181  2018                                         JayLayback
# 10182  1994                                                FFH
# 10183  2016                                        Velcro Mary
# 10184  2012                                    Marco Benevento
# 10173    0.0613   0.1480  130.041                 5                 10
# 10174    0.1530   0.2850   80.111                 4                 13
# 10175    0.2150   0.7100  137.867                 4                  4
# 10176    0.3320   0.9280  142.902                 4                  7
# 10177    0.2110   0.7660  102.563                 4                 63
# 10178    0.1040   0.0911  133.955                 4                  3
# 10179    0.2000   0.5860   78.398                 4                 39
# 10180    0.0991   0.2340   96.158                 4                 26
# 10181    0.2460   0.7240  169.972                 4                  1
# 10182    0.0984   0.5880  156.159                 4                 38
# 10183    0.0889   0.5380  113.007                 4                 14
# 10184    0.0805   0.6510   98.523                 4                 33
# 10185    0.0946   0.4830  100.016                 4                  1
# 10186    0.6870   0.6770   77.294                 4                 34
# 10187    0.1160   0.2180  122.996                 4                 15
# 10188    0.1170   0.8680  201.047                 4                 47
# 10189    0.3310   0.0915   86.455                 4                 31
# 10190    0.0656   0.2630  170.018                 4                  0
# 10191    0.2190   0.9120  121.123                 4                 11
# 10192    0.2320   0.9020   98.922                 4                  0
# 10193    0.1140   0.4310   70.073                 4                 72
# 10194    0.0955   0.0345  110.912                 4                 17
# 10195    0.3360   0.5770   84.890                 4                  8
# 10196    0.0914   0.3810  104.355                 4                  7
# 10197    0.0781   0.1780  120.144                 4                  7
# 10198    0.2090   0.2230  156.826                 4                 32
# 10199    0.1970   0.0583  114.100                 4                 48
#
#        Duration_ms  Time Signature
# 0           195717               4
# 1           200240               4
# 2           281240               4
# 3           173787               4
# 4           261333               4
# 5           297067               4
# 6           293840               4
# 7           130224               4
# 8           339893               4
# 9           301133               4
# 10          203120               4
# 11          277887               4
# 12          338840               4
# 13          239027               4
# 14          229560               4
# 15          170800               4
# 16          191613               3
# 17          201747               4
# 18          223427               4
# 19          270693               4
# 20          371160               4
# 21          283707               4
# 22          299052               4
# 23          192840               4
# 24          155387               4
# 25          209240               4
# 26          271573               4
# 27          271013               4
# 28          275707               4
# 29          123902               4
# ...            ...             ...
# 10170       221000               3
# 10171       201000               3
# 10172       175126               4
# 10173       207177               4
# 10174       106031               4
# 10175       190508               4
# 10176       173533               4
# 10177       274467               4
# 10178       338333               4
# 10179       116373               4
# 10180       237600               4
# 10181       241328               4
# 10182       230293               4
# 10183       252743               4
# 10184       230773               4
# 10185       192018               4
# 10186       227692               4
# 10187       378537               4
# 10188       193213               4
# 10189       325093               4
# 10190       262960               4
# 10191       181240               4
# 10192       168453               4
# 10193       251707               4
# 10194       132753               4
# 10195       192733               3
# 10196       146500               1
# 10197       364500               4
# 10198       127750               4
# 10199       249000               3
#
# [10200 rows x 18 columns]

# %%
df.to_csv("Finalrandomsongspls.csv", sep=',')

# %%
    songs=sp.search(q='year:'+'2015',limit=1,offset=8500,type="track", market="US")
    items = songs['tracks']['items']
    track=items[0]
    song_id = str(track["id"])
    track_features=sp.audio_features(song_id)
    features = np.array(track_features)[0]
    gettrack=features['uri']
    track_info = sp.track(gettrack)
    artist_name = artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album'][0]['name']
    track_year = track_info['album']['release_date'][0:4]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3sDbKMebVH2VYcRSl7u1VC'},
#     'href': 'https://api.spotify.com/v1/artists/3sDbKMebVH2VYcRSl7u1VC',
#     'id': '3sDbKMebVH2VYcRSl7u1VC',
#     'name': 'for KING & COUNTRY',
#     'type': 'artist',
#     'uri': 'spotify:artist:3sDbKMebVH2VYcRSl7u1VC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3JgsuH1i4ddVP4Ke5zf87I'},
#   'href': 'https://api.spotify.com/v1/albums/3JgsuH1i4ddVP4Ke5zf87I',
#   'id': '3JgsuH1i4ddVP4Ke5zf87I',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/af7f27478c956240812a02ae97248c106f4a0bb1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/95410f5ab45cdb684515343bfa3c0e1a4d086b1c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/55bd6aedc9cb660649e5e30fbd50e0e0ad77f153',
#     'width': 64}],
#   'name': 'RUN WILD. LIVE FREE. LOVE STRONG. (Deluxe Anniversary Edition)',
#   'release_date': '2015-10-22',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:3JgsuH1i4ddVP4Ke5zf87I'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3sDbKMebVH2VYcRSl7u1VC'},
#    'href': 'https://api.spotify.com/v1/artists/3sDbKMebVH2VYcRSl7u1VC',
#    'id': '3sDbKMebVH2VYcRSl7u1VC',
#    'name': 'for KING & COUNTRY',
#    'type': 'artist',
#    'uri': 'spotify:artist:3sDbKMebVH2VYcRSl7u1VC'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 258079,
#  'explicit': False,
#  'external_ids': {'isrc': 'USWR61401020'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0xB6FulVeQ6UEyc8fe79hQ'},
#  'href': 'https://api.spotify.com/v1/tracks/0xB6FulVeQ6UEyc8fe79hQ',
#  'id': '0xB6FulVeQ6UEyc8fe79hQ',
#  'is_local': False,
#  'name': 'Already Home',
#  'popularity': 40,
#  'preview_url': 'https://p.scdn.co/mp3-preview/720a50ce64c064193feb09503cc85fc69d9f5a33?cid=a31e2c1446fd4e6aa11476d8532fc939',
#  'track_number': 12,
#  'type': 'track',
#  'uri': 'spotify:track:0xB6FulVeQ6UEyc8fe79hQ'}

# %%
track_name = track_info['name']
artist_name
# Out:
# 'for KING & COUNTRY'
