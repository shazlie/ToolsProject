# %% [markdown]
# ## We already have the top songs, but at this point we would like to extract 5000 random songs from Spotify
# #### Work by: Naif

# %% [markdown]
# #### 1) Create a function to extract random songs

# %%
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id="a31e2c1446fd4e6aa11476d8532fc939",client_secret="b52f884f9d4f464eba58daf0d5180ea4")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


def get_randomsong_features():
    
    randomSongsArray = ['%25a%25', 'a%25', '%25a',
                        '%25e%25', 'e%25', '%25e',
                        '%25i%25', 'i%25', '%25i',
                        '%25o%25', 'o%25', '%25o',
                        '%25u%25', 'u%25', '%25u']
    randomSongs = random.choice(randomSongsArray)
    
    # generate a random offset
    rand1to1000 = range(1,1000)
    RandomOffset=random.choice(rand1to1000)

    songs=sp.search(q='year:2000-2018',limit=1,offset=RandomOffset,type="track",market="US")

    items = songs['tracks']['items']
    track=items[0]
    song_id = str(track["id"])
    track_features=sp.audio_features(song_id)
    features = np.array(track_features)[0]
    gettrack=features['uri']
    track_info = sp.track(gettrack)
    artist_name = artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    track_year = track_info['album']['release_date'][0:4]
    return features

# %% [markdown]
# ##### For loop for 5000 and append to a list

# %%
songs_features=[]
for i in range(0,5000):
    danceability, energy, key, loudness, mode,speechiness,acousticness, instrumentalness, liveness, valence, tempo, type_, id_,uri, track_href,analysis_url,duration_ms, time_signature=get_randomsong_features().values()
    track_info = sp.track(uri)
    artist_name = artist_name = track_info['album']['artists'][0]['name']
    track_name = track_info['album']['name']
    track_year = track_info['album']['release_date'][0:4]
    songs_features.append((track_year,artist_name,track_name,danceability, energy, key, loudness, mode, speechiness,acousticness, instrumentalness, liveness, valence, tempo,duration_ms, time_signature))

# %%
# Create a DataFrame 
import pandas as pd

columns_ = ["Year", "Artist", "Track", "Danceability","Energy", "Key", "Loudness", "Mode", "Speechiness", "Acousticness",
          "Instrumentalness", "Liveness", "Valence", "Tempo", "Duration_ms", "Time Signature"]
df =pd.DataFrame(songs_features, columns=columns_)
df
# Out:
#       Year                      Artist  \
# 0     2018               Billie Eilish
# 1     2009               Michael Bublé
# 2     2016               Ariana Grande
# 3     2009     Five Finger Death Punch
# 4     2016                Hoodie Allen
# 5     2017                   Mac Ayres
# 6     2014                 ScHoolboy Q
# 7     2018              Mumford & Sons
# 8     2007                  Kanye West
# 9     2007                     Beyoncé
# 10    2017               Young Scooter
# 11    2016                   Vic Mensa
# 12    2017                 Chris Young
# 13    2018                       Logic
# 14    2017                       potsu
# 15    2018                XXXTENTACION
# 16    2014                     J. Cole
# 17    2014                Clean Bandit
# 18    2018                          RM
# 19    2016                         BTS
# 20    2018             Lauren Jauregui
# 21    2018                 Post Malone
# 22    2010             Various Artists
# 23    2016                  Yung Gravy
# 24    2018                     6ix9ine
# 25    2017                   Lady Gaga
# 26    2015                       Drake
# 27    2014                     Beyoncé
# 28    2018           Foster The People
# 29    2017               Darius Rucker
# ...    ...                         ...
# 4970  2018                         Sia
# 4971  2018                    Lil Baby
# 4972  2014                 Eric Church
# 4973  2015             The Revivalists
# 4974  2018                  Luke Combs
# 4975  2013                  Disclosure
# 4976  2018                  YBN Nahmir
# 4977  2018            The Chainsmokers
# 4978  2018  YoungBoy Never Broke Again
# 4979  2018                       Quavo
# 4980  2001                      Sum 41
# 4981  2017                   Sam Smith
# 4993   10    -4.126     1       0.0550      0.053700          0.000000
# 4994   11    -4.531     0       0.0349      0.002160          0.000003
# 4995    6    -9.326     0       0.3260      0.293000          0.000000
# 4996    3    -5.835     1       0.0439      0.008470          0.000000
# 4997   10    -7.700     1       0.0299      0.918000          0.000000
# 4998    2    -9.732     1       0.0357      0.328000          0.015000
# 4999   10    -3.201     0       0.0597      0.002270          0.000000
#
#       Liveness  Valence    Tempo  Duration_ms  Time Signature
# 0       0.2260   0.4510  124.999       198684               4
# 1       0.1090   0.7960  122.580       244587               4
# 2       0.1620   0.4320  131.005       194840               4
# 3       0.0904   0.1700  114.025       262440               4
# 4       0.1730   0.3790   72.946       188040               4
# 5       0.1470   0.2170   91.367       314358               4
# 6       0.0585   0.5800  133.922       278067               3
# 7       0.0917   0.0632   99.966       269868               4
# 8       0.4670   0.4540   84.267       207000               4
# 9       0.1670   0.5090  175.868       227853               4
# 10      0.1110   0.3010  143.027       247066               4
# 11      0.0635   0.4810   79.175       258120               4
# 12      0.3890   0.6340   92.003       178253               4
# 13      0.3790   0.7680   90.933       487960               4
# 14      0.1060   0.5460  134.067       118302               4
# 15      0.1000   0.2390  180.055        80190               4
# 16      0.1190   0.3990   75.555       211680               1
# 17      0.1930   0.5490  120.970       227833               4
# 18      0.1320   0.0964   85.971       194384               4
# 19      0.1220   0.5360   99.930       203352               4
# 20      0.1240   0.4520  180.080       204067               3
# 21      0.2610   0.2520   78.395       112013               4
# 22      0.0897   0.3850  108.066       152333               4
# 23      0.1070   0.6690  106.320       210861               4
# 24      0.1250   0.2860  102.063       217822               4
# 25      0.0893   0.5160  100.002       211364               4
# 26      0.3410   0.1640  114.812       275840               4
# 27      0.1810   0.4010  140.030       323480               4
# 28      0.0438   0.6090  114.020       211920               4
# 29      0.0308   0.6660  142.016       197053               4
# ...        ...      ...      ...          ...             ...
# 4970    0.1210   0.5670  158.946       213040               4
# 4971    0.0789   0.6580  158.953       203881               4
# 4972    0.0885   0.5560  144.000       262280               4
# 4973    0.1250   0.7220  101.050       274093               4
# 4974    0.1430   0.6410   75.218       198880               4
# 4975    0.0895   0.5210  121.985       255632               4
# 4976    0.1820   0.4740   83.755       180389               4
# 4977    0.0662   0.4740  105.159       199227               4
# 4978    0.1110   0.3480  135.040       167277               4
# 4979    0.3590   0.5290  153.992       236948               4
# 4980    0.0769   0.5730   98.075       178267               4
# 4981    0.0858   0.1480  175.515       221596               3
# 4982    0.3570   0.2350   92.027       342821               4
# 4983    0.4540   0.0282  166.299       114679               1
# 4984    0.3340   0.2870  135.995       191252               4
# 4985    0.3480   0.3320  140.055       238400               3
# 4986    0.0843   0.4490   96.840       235540               4
# 4987    0.1110   0.3320   96.729       230711               3
# 4988    0.3480   0.3320  140.055       238400               3
# 4989    0.1040   0.4220  154.983       238614               4
# 4990    0.0828   0.7150  139.956       193253               4
# 4991    0.1570   0.5490  130.007       142498               4
# 4992    0.6070   0.5380  128.906       353960               3
# 4993    0.1600   0.4140  103.970       219520               4
# 4994    0.2400   0.9650  144.998       206840               4
# 4995    0.1220   0.8900  140.040       193776               4
# 4996    0.1610   0.3710  112.960       218013               4
# 4997    0.1370   0.2180  171.232       204326               3
# 4998    0.0873   0.4340  139.995       203701               4
# 4999    0.1220   0.5360   99.930       203352               4
#
# [5000 rows x 16 columns]

# %%
df.to_csv("random5000songs.csv", sep='\t')
